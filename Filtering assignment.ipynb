# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_excel('Adidas US Sales Datasets.xlsx')
df
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Ques1. Display all rows where Region is "Northeast"

# %%
sdf = df.loc[df['Region'] == 'Northeast']
sdf
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Filter rows where Units Sold is greater than 1000.

# %%
mdf = df.loc[df['Units Sold'] >1000 ]
mdf
# Out:
#            Retailer Invoice Date     Region           State           City  \
# 0       Foot Locker   2020-01-01  Northeast        New York       New York
# 6       Foot Locker   2020-01-07  Northeast        New York       New York
# 12      Foot Locker   2020-01-25  Northeast        New York       New York
# 18      Foot Locker   2020-01-31  Northeast        New York       New York
# 24      Foot Locker   2020-02-06  Northeast        New York       New York
# 30      Foot Locker   2020-03-04  Northeast        New York       New York
# 35      Foot Locker   2020-03-09  Northeast        New York       New York
# 36      Foot Locker   2020-03-10  Northeast        New York       New York
# 37      Foot Locker   2020-03-11  Northeast        New York       New York
# 41      Foot Locker   2020-03-15  Northeast        New York       New York
# 42      Foot Locker   2020-03-16  Northeast        New York       New York
# ...

# %% [markdown]
# Show records where Price per Unit is equal to $50.00.

# %%
df.loc[df['Price per Unit']==50.00]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 5     Foot Locker   2020-01-06  Northeast       New York    New York
# 6     Foot Locker   2020-01-07  Northeast       New York    New York
# 7     Foot Locker   2020-01-08  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9559       Amazon   2021-11-11  Northeast        Vermont  Burlington
# 9602       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 9625  Foot Locker   2021-10-19  Northeast  New Hampshire  Manchester
# 9637  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
#
#                       Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Get all rows where Sales Method is "In-store".

# %%
df.loc[df['Sales Method'] == 'In-store']
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 3839       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 3840       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 3841       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 3842       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 3843       Amazon   2021-07-17  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Select records where Retailer is "Foot Locker" and City is "New York".

# %%
df.loc[(df['Retailer'] == 'Foot Locker') & (df['City'] == 'New York')]
# Out:
#          Retailer Invoice Date     Region     State      City  \
# 0     Foot Locker   2020-01-01  Northeast  New York  New York
# 1     Foot Locker   2020-01-02  Northeast  New York  New York
# 2     Foot Locker   2020-01-03  Northeast  New York  New York
# 3     Foot Locker   2020-01-04  Northeast  New York  New York
# 4     Foot Locker   2020-01-05  Northeast  New York  New York
# ...           ...          ...        ...       ...       ...
# 7817  Foot Locker   2020-03-15  Northeast  New York  New York
# 7818  Foot Locker   2020-03-16  Northeast  New York  New York
# 7819  Foot Locker   2020-03-17  Northeast  New York  New York
# 7820  Foot Locker   2020-03-18  Northeast  New York  New York
# 7821  Foot Locker   2020-03-31  Northeast  New York  New York
#
#                         Product  Price per Unit  Units Sold Sales Method
# 0         Men's Street Footwear            50.0        1200     In-store
# 1       Men's Athletic Footwear            50.0        1000     In-store
# ...

# %% [markdown]
# Filter rows where Units Sold is not equal to 1000.

# %%
df.loc[df['Units Sold'] != 1000]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# 6     Foot Locker   2020-01-07  Northeast       New York    New York
# 7     Foot Locker   2020-01-08  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Show records where Units Sold is greater than or equal to 900.

# %%
df.loc[df['Units Sold'] >= 900]
# Out:
#            Retailer Invoice Date     Region           State       City  \
# 0       Foot Locker   2020-01-01  Northeast        New York   New York
# 1       Foot Locker   2020-01-02  Northeast        New York   New York
# 2       Foot Locker   2020-01-03  Northeast        New York   New York
# 4       Foot Locker   2020-01-05  Northeast        New York   New York
# 5       Foot Locker   2020-01-06  Northeast        New York   New York
# ...             ...          ...        ...             ...        ...
# 2403  Sports Direct   2021-07-02  Southeast  North Carolina  Charlotte
# 2409  Sports Direct   2021-08-03  Southeast  North Carolina  Charlotte
# 2415  Sports Direct   2021-09-02  Southeast  North Carolina  Charlotte
# 2433  Sports Direct   2021-12-02  Southeast  North Carolina  Charlotte
# 2475         Amazon   2021-07-09    Midwest            Ohio   Columbus
#
#                       Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Filter rows where Price per Unit is less than $50.00

# %%
df.loc[df['Price per Unit']<50.00]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 8     Foot Locker   2020-01-21  Northeast       New York    New York
# 9     Foot Locker   2020-01-22  Northeast       New York    New York
# 14    Foot Locker   2020-01-27  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9642  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Display all rows where Units Sold is between 900 and 1200.

# %%
df.loc[df['Units Sold'].between(900,1200)]
# Out:
#            Retailer Invoice Date     Region           State       City  \
# 0       Foot Locker   2020-01-01  Northeast        New York   New York
# 1       Foot Locker   2020-01-02  Northeast        New York   New York
# 2       Foot Locker   2020-01-03  Northeast        New York   New York
# 4       Foot Locker   2020-01-05  Northeast        New York   New York
# 5       Foot Locker   2020-01-06  Northeast        New York   New York
# ...             ...          ...        ...             ...        ...
# 2403  Sports Direct   2021-07-02  Southeast  North Carolina  Charlotte
# 2409  Sports Direct   2021-08-03  Southeast  North Carolina  Charlotte
# 2415  Sports Direct   2021-09-02  Southeast  North Carolina  Charlotte
# 2433  Sports Direct   2021-12-02  Southeast  North Carolina  Charlotte
# 2475         Amazon   2021-07-09    Midwest            Ohio   Columbus
#
#                       Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Show all records where Region is "Northeast" and State is "New York".

# %%
df.loc[(df['Region'] == 'Northeast') & (df['State'] == 'New York')]
# Out:
#            Retailer Invoice Date     Region     State      City  \
# 0       Foot Locker   2020-01-01  Northeast  New York  New York
# 1       Foot Locker   2020-01-02  Northeast  New York  New York
# 2       Foot Locker   2020-01-03  Northeast  New York  New York
# 3       Foot Locker   2020-01-04  Northeast  New York  New York
# 4       Foot Locker   2020-01-05  Northeast  New York  New York
# ...             ...          ...        ...       ...       ...
# 7843        Walmart   2020-07-18  Northeast  New York  New York
# 7844  Sports Direct   2020-07-19  Northeast  New York  New York
# 7845  Sports Direct   2020-07-20  Northeast  New York  New York
# 7846  Sports Direct   2020-07-21  Northeast  New York  New York
# 7847  Sports Direct   2020-07-22  Northeast  New York  New York
#
#                         Product  Price per Unit  Units Sold Sales Method
# 0         Men's Street Footwear            50.0        1200     In-store
# ...

# %% [markdown]
# Multiple Conditions

# %% [markdown]
# Display rows where Units Sold > 1000 and Price per Unit > $45.00.

# %%
df.loc[(df['Units Sold'] > 1000) & (df['Price per Unit']> 45.00)]
# Out:
#            Retailer Invoice Date     Region           State           City  \
# 0       Foot Locker   2020-01-01  Northeast        New York       New York
# 6       Foot Locker   2020-01-07  Northeast        New York       New York
# 12      Foot Locker   2020-01-25  Northeast        New York       New York
# 18      Foot Locker   2020-01-31  Northeast        New York       New York
# 24      Foot Locker   2020-02-06  Northeast        New York       New York
# 30      Foot Locker   2020-03-04  Northeast        New York       New York
# 35      Foot Locker   2020-03-09  Northeast        New York       New York
# 36      Foot Locker   2020-03-10  Northeast        New York       New York
# 37      Foot Locker   2020-03-11  Northeast        New York       New York
# 41      Foot Locker   2020-03-15  Northeast        New York       New York
# 42      Foot Locker   2020-03-16  Northeast        New York       New York
# ...

# %% [markdown]
# Show rows where Units Sold < 1000 or Price per Unit < $45.00.

# %%
df.loc[(df['Units Sold'] < 1000) | (df['Price per Unit'] < 45.00)]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# 7     Foot Locker   2020-01-08  Northeast       New York    New York
# 8     Foot Locker   2020-01-21  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Filter rows where Units Sold > 800 and Units Sold < 1200.

# %%
df.loc[df['Units Sold'].between(800,1200)]
# Out:
#          Retailer Invoice Date     Region        State      City  \
# 0     Foot Locker   2020-01-01  Northeast     New York  New York
# 1     Foot Locker   2020-01-02  Northeast     New York  New York
# 2     Foot Locker   2020-01-03  Northeast     New York  New York
# 3     Foot Locker   2020-01-04  Northeast     New York  New York
# 4     Foot Locker   2020-01-05  Northeast     New York  New York
# ...           ...          ...        ...          ...       ...
# 2475       Amazon   2021-07-09    Midwest         Ohio  Columbus
# 2481       Amazon   2021-08-10    Midwest         Ohio  Columbus
# 2505       Amazon   2021-12-09    Midwest         Ohio  Columbus
# 2619  Foot Locker   2021-07-16      South  Mississippi   Jackson
# 2625      Walmart   2021-08-17      South  Mississippi   Jackson
#
#                         Product  Price per Unit  Units Sold Sales Method
# 0         Men's Street Footwear            50.0        1200     In-store
# ...

# %% [markdown]
# Select rows where Price per Unit equals $50.00 and Sales Method is "In-store".

# %%
df.loc[(df['Price per Unit'] == 50.00) & (df['Sales Method'] == 'In-store')]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 5     Foot Locker   2020-01-06  Northeast       New York    New York
# 6     Foot Locker   2020-01-07  Northeast       New York    New York
# 645     West Gear   2020-05-27       West       Colorado      Denver
# ...           ...          ...        ...            ...         ...
# 3820       Amazon   2021-03-17  Northeast  New Hampshire  Manchester
# 3824       Amazon   2021-03-17  Northeast  New Hampshire  Manchester
# 3825       Amazon   2021-04-18  Northeast  New Hampshire  Manchester
# 3826       Amazon   2021-04-18  Northeast  New Hampshire  Manchester
# 3830       Amazon   2021-04-18  Northeast  New Hampshire  Manchester
#
#                       Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Show records where Units Sold is either 850 or 900.

# %%
df.loc[(df['Units Sold'].isin([850,900]))]
# Out:
#          Retailer Invoice Date     Region           State         City  \
# 3     Foot Locker   2020-01-04  Northeast        New York     New York
# 4     Foot Locker   2020-01-05  Northeast        New York     New York
# 7     Foot Locker   2020-01-08  Northeast        New York     New York
# 10    Foot Locker   2020-01-23  Northeast        New York     New York
# 16    Foot Locker   2020-01-29  Northeast        New York     New York
# ...           ...          ...        ...             ...          ...
# 1977    West Gear   2021-08-17      South       Louisiana  New Orleans
# 2332  Foot Locker   2021-07-05  Southeast  South Carolina   Charleston
# 2338  Foot Locker   2021-08-06  Southeast  South Carolina   Charleston
# 2475       Amazon   2021-07-09    Midwest            Ohio     Columbus
# 2619  Foot Locker   2021-07-16      South     Mississippi      Jackson
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Get rows where Units Sold is not in [850, 900, 1250].

# %%
df.loc[~(df['Units Sold'].isin([850,900,950]))]
# Out:
#            Retailer Invoice Date     Region           State        City  \
# 3       Foot Locker   2020-01-04  Northeast        New York    New York
# 4       Foot Locker   2020-01-05  Northeast        New York    New York
# 7       Foot Locker   2020-01-08  Northeast        New York    New York
# 8       Foot Locker   2020-01-21  Northeast        New York    New York
# 10      Foot Locker   2020-01-23  Northeast        New York    New York
# ...             ...          ...        ...             ...         ...
# 2332    Foot Locker   2021-07-05  Southeast  South Carolina  Charleston
# 2338    Foot Locker   2021-08-06  Southeast  South Carolina  Charleston
# 2397  Sports Direct   2021-06-04  Southeast  North Carolina   Charlotte
# 2475         Amazon   2021-07-09    Midwest            Ohio    Columbus
# 2619    Foot Locker   2021-07-16      South     Mississippi     Jackson
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Select all rows where Product is in a list of specific product types (e.g. ["Men's Apparel", "Women's Apparel"]).

# %%
df.loc[df['Product'].isin(['Men\'s Apparel', 'Women\'s Apparel'])]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# 5     Foot Locker   2020-01-06  Northeast       New York    New York
# 10    Foot Locker   2020-01-23  Northeast       New York    New York
# 11    Foot Locker   2020-01-24  Northeast       New York    New York
# 16    Foot Locker   2020-01-29  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9632  Foot Locker   2021-11-18  Northeast  New Hampshire  Manchester
# 9637  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9638  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
#
#               Product  Price per Unit  Units Sold Sales Method
# 4       Men's Apparel            60.0         900     In-store
# ...

# %% [markdown]
# Display all rows where Units Sold <= 1000 and Price per Unit >= $45.00

# %%
df.loc[(df['Units Sold'] <= 1000) & (df['Price per Unit'] >= 45.00 )]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# 5     Foot Locker   2020-01-06  Northeast       New York    New York
# 7     Foot Locker   2020-01-08  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9635  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9636  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9637  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9638  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Filter all rows where both City and State are "New York"

# %%
df.loc[(df['City']== 'New York') & (df['State'] == 'New York') ]
# Out:
#            Retailer Invoice Date     Region     State      City  \
# 0       Foot Locker   2020-01-01  Northeast  New York  New York
# 1       Foot Locker   2020-01-02  Northeast  New York  New York
# 2       Foot Locker   2020-01-03  Northeast  New York  New York
# 3       Foot Locker   2020-01-04  Northeast  New York  New York
# 4       Foot Locker   2020-01-05  Northeast  New York  New York
# ...             ...          ...        ...       ...       ...
# 7843        Walmart   2020-07-18  Northeast  New York  New York
# 7844  Sports Direct   2020-07-19  Northeast  New York  New York
# 7845  Sports Direct   2020-07-20  Northeast  New York  New York
# 7846  Sports Direct   2020-07-21  Northeast  New York  New York
# 7847  Sports Direct   2020-07-22  Northeast  New York  New York
#
#                         Product  Price per Unit  Units Sold Sales Method
# 0         Men's Street Footwear            50.0        1200     In-store
# ...

# %% [markdown]
# Show rows where Price per Unit is $45.00 or $50.00.

# %%
df.loc[df['Price per Unit'].isin([45.00,50.00])]
# Out:
#            Retailer Invoice Date     Region          State        City  \
# 3640    Foot Locker   2021-09-06  Northeast   Rhode Island  Providence
# 3689  Sports Direct   2021-05-13  Northeast  Massachusetts      Boston
# 3690  Sports Direct   2021-05-13  Northeast  Massachusetts      Boston
# 3695  Sports Direct   2021-06-15  Northeast  Massachusetts      Boston
# 3696  Sports Direct   2021-06-15  Northeast  Massachusetts      Boston
# ...             ...          ...        ...            ...         ...
# 9332  Sports Direct   2021-09-03  Northeast    Connecticut    Hartford
# 9345    Foot Locker   2021-12-03  Northeast    Connecticut    Hartford
# 9531         Amazon   2021-07-10  Northeast        Vermont  Burlington
# 9548         Amazon   2021-09-10  Northeast        Vermont  Burlington
# 9613         Amazon   2021-08-18  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Using .isin() and .between()

# %% [markdown]
# Filter rows where Region is in ["Northeast", "Southwest"].

# %%
df.loc[df['Region'].isin(['Northeast','Southwest'])]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Display all rows where Units Sold is between 1000 and 1200 (inclusive).

# %%
df.loc[df['Units Sold'].between(1000,1200)]
# Out:
#            Retailer Invoice Date     Region           State           City  \
# 0       Foot Locker   2020-01-01  Northeast        New York       New York
# 1       Foot Locker   2020-01-02  Northeast        New York       New York
# 2       Foot Locker   2020-01-03  Northeast        New York       New York
# 5       Foot Locker   2020-01-06  Northeast        New York       New York
# 11      Foot Locker   2020-01-24  Northeast        New York       New York
# 18      Foot Locker   2020-01-31  Northeast        New York       New York
# 29      Foot Locker   2020-03-03  Northeast        New York       New York
# 31      Foot Locker   2020-03-05  Northeast        New York       New York
# 35      Foot Locker   2020-03-09  Northeast        New York       New York
# 37      Foot Locker   2020-03-11  Northeast        New York       New York
# 41      Foot Locker   2020-03-15  Northeast        New York       New York
# ...

# %% [markdown]
# Select all rows where Price per Unit is between $45.00 and $60.00.

# %%
df.loc[df['Price per Unit'].between(45.00,60.00)]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# 5     Foot Locker   2020-01-06  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9634  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9635  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9636  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9637  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Get rows where Sales Method is in ["In-store", "Online"].

# %%
df.loc[df['Sales Method'].isin(['In-store','Online'])]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 7771  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 7772  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 7773  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 7774  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 7775  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Exclude all rows where Region is in ["Northwest", "Midwest"] using ~.

# %%
df.loc[~(df['Region'].isin(['Northwest','Midwest']))]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Show records where Units Sold is not between 900 and 1100.

# %%
df.loc[~(df['Units Sold'].between(900,1100))]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 6     Foot Locker   2020-01-07  Northeast       New York    New York
# 9     Foot Locker   2020-01-22  Northeast       New York    New York
# 12    Foot Locker   2020-01-25  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Get rows where both Region and Sales Method are in given lists.

# %%
df.loc[(df['Region'].isin(['Northeast', 'Southwest'])) &
       (df['Sales Method'].isin(['In-store', 'Online']))]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 7771  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 7772  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 7773  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 7774  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 7775  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Select rows where Price per Unit is between $40.00 and $50.00 and Units Sold > 900.

# %%
df.loc[(df['Price per Unit'].between(40.00,50.00)) & (df['Units Sold'] > 900)]
# Out:
#            Retailer Invoice Date     Region           State         City  \
# 0       Foot Locker   2020-01-01  Northeast        New York     New York
# 1       Foot Locker   2020-01-02  Northeast        New York     New York
# 2       Foot Locker   2020-01-03  Northeast        New York     New York
# 5       Foot Locker   2020-01-06  Northeast        New York     New York
# 6       Foot Locker   2020-01-07  Northeast        New York     New York
# 8       Foot Locker   2020-01-21  Northeast        New York     New York
# 11      Foot Locker   2020-01-24  Northeast        New York     New York
# 12      Foot Locker   2020-01-25  Northeast        New York     New York
# 13      Foot Locker   2020-01-26  Northeast        New York     New York
# 14      Foot Locker   2020-01-27  Northeast        New York     New York
# 17      Foot Locker   2020-01-30  Northeast        New York     New York
# 18      Foot Locker   2020-01-31  Northeast        New York     New York
# ...

# %% [markdown]
# Display rows where Units Sold is in [850, 1000, 1200, 1250].

# %%
df.loc[df['Units Sold'].isin([850,1000,1200,1250])]
# Out:
#            Retailer Invoice Date     Region        State           City  \
# 0       Foot Locker   2020-01-01  Northeast     New York       New York
# 1       Foot Locker   2020-01-02  Northeast     New York       New York
# 2       Foot Locker   2020-01-03  Northeast     New York       New York
# 3       Foot Locker   2020-01-04  Northeast     New York       New York
# 5       Foot Locker   2020-01-06  Northeast     New York       New York
# 6       Foot Locker   2020-01-07  Northeast     New York       New York
# 11      Foot Locker   2020-01-24  Northeast     New York       New York
# 16      Foot Locker   2020-01-29  Northeast     New York       New York
# 18      Foot Locker   2020-01-31  Northeast     New York       New York
# 27      Foot Locker   2020-02-09  Northeast     New York       New York
# 29      Foot Locker   2020-03-03  Northeast     New York       New York
# 30      Foot Locker   2020-03-04  Northeast     New York       New York
# ...

# %% [markdown]
# Filter out rows where Units Sold is in [850, 900].

# %%
df.loc[df['Units Sold'].isin([850,900])]
# Out:
#          Retailer Invoice Date     Region           State         City  \
# 3     Foot Locker   2020-01-04  Northeast        New York     New York
# 4     Foot Locker   2020-01-05  Northeast        New York     New York
# 7     Foot Locker   2020-01-08  Northeast        New York     New York
# 10    Foot Locker   2020-01-23  Northeast        New York     New York
# 16    Foot Locker   2020-01-29  Northeast        New York     New York
# ...           ...          ...        ...             ...          ...
# 1977    West Gear   2021-08-17      South       Louisiana  New Orleans
# 2332  Foot Locker   2021-07-05  Southeast  South Carolina   Charleston
# 2338  Foot Locker   2021-08-06  Southeast  South Carolina   Charleston
# 2475       Amazon   2021-07-09    Midwest            Ohio     Columbus
# 2619  Foot Locker   2021-07-16      South     Mississippi      Jackson
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Using .iloc for positional filtering

# %% [markdown]
# Display the first 10 rows using .iloc

# %%
df.iloc[:10]
# Out:
#       Retailer Invoice Date     Region     State      City  \
# 0  Foot Locker   2020-01-01  Northeast  New York  New York
# 1  Foot Locker   2020-01-02  Northeast  New York  New York
# 2  Foot Locker   2020-01-03  Northeast  New York  New York
# 3  Foot Locker   2020-01-04  Northeast  New York  New York
# 4  Foot Locker   2020-01-05  Northeast  New York  New York
# 5  Foot Locker   2020-01-06  Northeast  New York  New York
# 6  Foot Locker   2020-01-07  Northeast  New York  New York
# 7  Foot Locker   2020-01-08  Northeast  New York  New York
# 8  Foot Locker   2020-01-21  Northeast  New York  New York
# 9  Foot Locker   2020-01-22  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold Sales Method
# 0      Men's Street Footwear            50.0        1200     In-store
# 1    Men's Athletic Footwear            50.0        1000     In-store
# 2    Women's Street Footwear            40.0        1000     In-store
# ...

# %% [markdown]
# Show rows from index position 100 to 120.

# %%
df.iloc[100:121]
# Out:
#     Retailer Invoice Date Region  State     City                    Product  \
# 100  Walmart   2020-08-20  South  Texas  Houston    Women's Street Footwear
# 101  Walmart   2020-08-21  South  Texas  Houston  Women's Athletic Footwear
# 102  Walmart   2020-08-22  South  Texas  Houston              Men's Apparel
# 103  Walmart   2020-08-23  South  Texas  Houston            Women's Apparel
# 104  Walmart   2020-08-24  South  Texas  Houston      Men's Street Footwear
# 105  Walmart   2020-08-25  South  Texas  Houston    Men's Athletic Footwear
# 106  Walmart   2020-08-26  South  Texas  Houston    Women's Street Footwear
# 107  Walmart   2020-08-27  South  Texas  Houston  Women's Athletic Footwear
# 108  Walmart   2020-08-28  South  Texas  Houston              Men's Apparel
# 109  Walmart   2020-08-29  South  Texas  Houston            Women's Apparel
# 110  Walmart   2020-08-30  South  Texas  Houston      Men's Street Footwear
# ...

# %% [markdown]
# Display every 5th row using .iloc.

# %%
df.iloc[::5]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 5     Foot Locker   2020-01-06  Northeast       New York    New York
# 10    Foot Locker   2020-01-23  Northeast       New York    New York
# 15    Foot Locker   2020-01-28  Northeast       New York    New York
# 20    Foot Locker   2020-02-02  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9625  Foot Locker   2021-10-19  Northeast  New Hampshire  Manchester
# 9630  Foot Locker   2021-11-18  Northeast  New Hampshire  Manchester
# 9635  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9640  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Show the last 10 rows using negative indices.

# %%
df.iloc[-10:]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 9638  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9639  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9640  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9641  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9642  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# 9638            Women's Apparel            61.0         144       Outlet
# ...

# %% [markdown]
# Display alternate rows from the dataset (even index rows).

# %%
df.iloc[::2]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# 6     Foot Locker   2020-01-07  Northeast       New York    New York
# 8     Foot Locker   2020-01-21  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9638  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9640  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9642  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Select rows between position 50 and 60 where Units Sold > 1000.

# %%
df.iloc[50:61][df.iloc[50:61]['Units Sold'] > 1000]
# Out:
#    Retailer Invoice Date     Region     State      City  \
# 56  Walmart   2020-04-27  Northeast  New York  New York
#
#                   Product  Price per Unit  Units Sold Sales Method
# 56  Men's Street Footwear            65.0        1150       Outlet

# %% [markdown]
# Using .iloc, get the first 3 rows and specific columns (Retailer, Units Sold).

# %%
df.iloc[:4][['Retailer','Units Sold']]
# Out:
#       Retailer  Units Sold
# 0  Foot Locker        1200
# 1  Foot Locker        1000
# 2  Foot Locker        1000
# 3  Foot Locker         850

# %% [markdown]
# Get rows from index 10 to 20 for columns Product and Units Sold.

# %%
df.iloc[10:21][['Product','Units Sold']]
# Out:
#                       Product  Units Sold
# 10              Men's Apparel         900
# 11            Women's Apparel        1000
# 12      Men's Street Footwear        1220
# 13    Men's Athletic Footwear         925
# 14    Women's Street Footwear         950
# 15  Women's Athletic Footwear         800
# 16              Men's Apparel         850
# 17            Women's Apparel         950
# 18      Men's Street Footwear        1200
# 19    Men's Athletic Footwear         900
# 20    Women's Street Footwear         900

# %% [markdown]
# Fetch rows using a list of specific index positions (e.g., [0, 2, 5, 7]).

# %%
df.iloc[[0,2,5,7]]
# Out:
#       Retailer Invoice Date     Region     State      City  \
# 0  Foot Locker   2020-01-01  Northeast  New York  New York
# 2  Foot Locker   2020-01-03  Northeast  New York  New York
# 5  Foot Locker   2020-01-06  Northeast  New York  New York
# 7  Foot Locker   2020-01-08  Northeast  New York  New York
#
#                    Product  Price per Unit  Units Sold Sales Method
# 0    Men's Street Footwear            50.0        1200     In-store
# 2  Women's Street Footwear            40.0        1000     In-store
# 5          Women's Apparel            50.0        1000     In-store
# 7  Men's Athletic Footwear            50.0         900       Outlet

# %% [markdown]
# Select the middle 10% of records using .iloc

# %%
middle_start = int(len(df) * 0.45)
middle_end = int(len(df) * 0.55)
df.iloc[middle_start:middle_end]
# Out:
#          Retailer Invoice Date     Region         State          City  \
# 4341  Foot Locker   2021-11-16  Northeast  Pennsylvania  Philadelphia
# 4342  Foot Locker   2021-11-17  Northeast  Pennsylvania  Philadelphia
# 4343  Foot Locker   2021-11-18  Northeast  Pennsylvania  Philadelphia
# 4344  Foot Locker   2021-11-19  Northeast  Pennsylvania  Philadelphia
# 4345  Foot Locker   2021-11-20  Northeast  Pennsylvania  Philadelphia
# ...           ...          ...        ...           ...           ...
# 5301      Walmart   2021-10-17  Southeast       Florida       Orlando
# 5302      Walmart   2021-10-17  Southeast       Florida       Orlando
# 5303      Walmart   2021-10-17  Southeast       Florida       Orlando
# 5304      Walmart   2021-10-17  Southeast       Florida       Orlando
# 5305      Walmart   2021-10-17  Southeast       Florida       Orlando
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Use .loc to select rows where Price per Unit > $45.00.

# %%
df.loc[df['Price per Unit']>45.00]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# 5     Foot Locker   2020-01-06  Northeast       New York    New York
# 6     Foot Locker   2020-01-07  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9635  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9636  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9637  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9638  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Use .loc to select rows where Units Sold < 1000 and Product is "Men's Street Footwear".

# %%
df.loc[(df['Units Sold']<1000) & (df['Product'] == 'Men\'s Street Footwear')]
# Out:
#            Retailer Invoice Date     Region          State        City  \
# 68    Sports Direct   2020-07-19  Northeast       New York    New York
# 74    Sports Direct   2020-07-25      South          Texas     Houston
# 80    Sports Direct   2020-07-31      South          Texas     Houston
# 86    Sports Direct   2020-08-06      South          Texas     Houston
# 92          Walmart   2020-08-12      South          Texas     Houston
# ...             ...          ...        ...            ...         ...
# 9621    Foot Locker   2021-10-19  Northeast  New Hampshire  Manchester
# 9627    Foot Locker   2021-11-18  Northeast  New Hampshire  Manchester
# 9633    Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9639    Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645    Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                     Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Using .loc, filter rows where Sales Method is "In-store" and Region is "Northeast".

# %%
df.loc[(df['Sales Method']== 'In-store') & (df['Region'] == 'Northeast')]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 3839       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 3840       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 3841       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 3842       Amazon   2021-06-19  Northeast  New Hampshire  Manchester
# 3843       Amazon   2021-07-17  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Using .loc, select rows where Units Sold > 1000 or Product is "Women's Apparel".

# %%
df.loc[(df["Units Sold"]>1000) | (df['Product'] == 'Women\'s Apparel')]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 5     Foot Locker   2020-01-06  Northeast       New York    New York
# 6     Foot Locker   2020-01-07  Northeast       New York    New York
# 11    Foot Locker   2020-01-24  Northeast       New York    New York
# 12    Foot Locker   2020-01-25  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9620       Amazon   2021-09-17  Northeast  New Hampshire  Manchester
# 9626  Foot Locker   2021-10-19  Northeast  New Hampshire  Manchester
# 9632  Foot Locker   2021-11-18  Northeast  New Hampshire  Manchester
# 9638  Foot Locker   2021-12-17  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
#
#                     Product  Price per Unit  Units Sold Sales Method
# 0     Men's Street Footwear            50.0        1200     In-store
# ...

# %% [markdown]
# With .loc, exclude rows where Price per Unit equals $50.00.

# %%
df.loc[~(df['Price per Unit'] == 50.00)]
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# 8     Foot Locker   2020-01-21  Northeast       New York    New York
# 9     Foot Locker   2020-01-22  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9642  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Updating Records using .loc

# %% [markdown]
# Update Sales Method to "Online" where Units Sold > 1200. - problem

# %%
df.loc[df['Units Sold'] > 1200, 'Sales Method' ] == ' online'
df
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Change Price per Unit to $55.00 for all "Men's Apparel" products.

# %%
df.loc[df['Product'] == 'Men\'s Apparel', 'Price per Unit'] = 55.00
df
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01  Northeast       New York    New York
# 1     Foot Locker   2020-01-02  Northeast       New York    New York
# 2     Foot Locker   2020-01-03  Northeast       New York    New York
# 3     Foot Locker   2020-01-04  Northeast       New York    New York
# 4     Foot Locker   2020-01-05  Northeast       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Set Region to "East" for all rows where State is "New York".

# %%
df.loc[df['State'] == 'New York' , 'Region' ] = 'East'
df
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01       East       New York    New York
# 1     Foot Locker   2020-01-02       East       New York    New York
# 2     Foot Locker   2020-01-03       East       New York    New York
# 3     Foot Locker   2020-01-04       East       New York    New York
# 4     Foot Locker   2020-01-05       East       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...

# %% [markdown]
# Increase Units Sold by 10% for all rows where Product contains "Footwear". Problem

# %% [markdown]
# Update multiple columns — set Price per Unit = "$60.00" and Sales Method = "Online" where Units Sold > 1000.

# %%
df.loc[df["Units Sold"] > 1000, ["Price per Unit", "Sales Method"]] = [60.00, "Online"]
df
# Out:
#          Retailer Invoice Date     Region          State        City  \
# 0     Foot Locker   2020-01-01       East       New York    New York
# 1     Foot Locker   2020-01-02       East       New York    New York
# 2     Foot Locker   2020-01-03       East       New York    New York
# 3     Foot Locker   2020-01-04       East       New York    New York
# 4     Foot Locker   2020-01-05       East       New York    New York
# ...           ...          ...        ...            ...         ...
# 9643  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker   2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker   2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold Sales Method
# ...
